# %% [markdown]
# # Import Library

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import tensorflow as tf
import numpy as np
import pickle

# %% [markdown]
# # Load Dataset

# %%
df = pd.read_csv('/content/dataset_parfum_gabungan.csv')
df
# Out:
#           No  ID_Perfume                   perfume                brand  \
# 0          1   HRMN-0001                    glitch              mykonos
# 1          2   HRMN-0002                    invade              mykonos
# 2          3   HRMN-0003                Cafe Drops              mykonos
# 3          4   HRMN-0004                Pink Drops              mykonos
# 4          5   HRMN-0005        Pandan Sticky Rice              mykonos
# ...      ...         ...                       ...                  ...
# 25122  25123  FRGN-25123                  floratta          o-boticario
# 25123  25124  FRGN-25124           cheval-d-arabie  sultan-pasha-attars
# 25124  25125  FRGN-25125                     khaox     darkbeat-parfums
# 25125  25126  FRGN-25126                 aoud-no-1  parfumerie-bruckner
# 25126  25127  FRGN-25127  narmar-extrait-de-parfum       nilafar-du-nil
#
#                                                top notes  \
# 0      sicilian bergamot, apple, grapefruit, charred ...
# 1               pink pepper, lavender absolute, juniper.
# 2                                Orchid, Jasmine, coffee
# 3                   Strawberry Preserve, Almond, Caramel
# 4                                 Rice, Almond, Lactonic
# ...                                                  ...
# 25122                                ozonic notes, peach
# 25123  taif rose, indian oud, white rose, olibanum, e...
# 25124                                    mint, lime, rum
# 25125                              apple, peach, saffron
# 25126  cardamom, lavender, juniper, bergamot, clary sage
#
#                                                mid notes  \
# 0      Lavender, artemesia, lily of the valley, pink ...
# 1                     cashmeran, cinnamon bark, caramel.
# 2                     Vanilla, Caramel, Tonka Bean, Milk
# 3                                       Milk, Heliotrope
# 4       Jasmine, Ylang ylang, Iily of the valley, Pandan
# ...                                                  ...
# 25122                        lily-of-the-valley, jasmine
# 25123  bulgarian rose, indian oud, hay, leather, cive...
# 25124             lily-of-the-valley, fig leaf, cardamom
# 25125                      plum, orange blossom, jasmine
# 25126         cashmeran, rose, green tea, lily, cinnamon
#
#                                               base notes  is_lokal
# 0      white musk, cedarwood, moss, amber, patchouli,...      True
# 1                   amber, madagascar vanilla, drywoods.      True
# 2                           Amber, Musk, Wood, Patchouli      True
# 3                                    Vanilla, White musk      True
# 4                            Ambery, vanilla, sandalwood      True
# ...                                                  ...       ...
# 25122                                        musk, amber     False
# 25123  white amber, leather, hay, elemi resin, kyara ...     False
# 25124                    musk, oakmoss, amber, patchouli     False
# 25125                agarwood (oud), sandalwood, vanilla     False
# 25126  cashmeran, tobacco, oakmoss, suede, tonka bean...     False
#
# [25127 rows x 8 columns]

# %% [markdown]
# # Cleaning & Preprocessing

# %%
# Menghapus kolom No
df = df.drop('No', axis=1)

# %%
# Menggunakan Kolom-kolom Notes
df['Notes'] = df['top notes'].fillna('') + ', ' + df['mid notes'].fillna('') + ', ' + df['base notes'].fillna('')
df = df.drop(['top notes', 'mid notes', 'base notes'], axis=1)
df.head()
# Out:
#   ID_Perfume             perfume    brand  is_lokal  \
# 0  HRMN-0001              glitch  mykonos      True
# 1  HRMN-0002              invade  mykonos      True
# 2  HRMN-0003          Cafe Drops  mykonos      True
# 3  HRMN-0004          Pink Drops  mykonos      True
# 4  HRMN-0005  Pandan Sticky Rice  mykonos      True
#
#                                                Notes
# 0  sicilian bergamot, apple, grapefruit, charred ...
# 1  pink pepper, lavender absolute, juniper., cash...
# 2  Orchid, Jasmine, coffee, Vanilla, Caramel, Ton...
# 3  Strawberry Preserve, Almond, Caramel, Milk, He...
# 4  Rice, Almond, Lactonic, Jasmine, Ylang ylang, ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25127 entries, 0 to 25126
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID_Perfume  25127 non-null  object
#  1   perfume     25127 non-null  object
#  2   brand       25127 non-null  object
#  3   is_lokal    25127 non-null  bool
#  4   Notes       25127 non-null  object
# dtypes: bool(1), object(4)
# memory usage: 809.9+ KB

# %%
# Mengecek Missing value
df.isna().sum()
# Out:
# ID_Perfume    0
# perfume       0
# brand         0
# is_lokal      0
# Notes         0
# dtype: int64

# %%
# Melihat data yang duplikat
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# mengecek Ada berapa brand
df['brand'].nunique()
# Out:
# 1194

# %%
df['Notes'] = df['Notes'].str.lower()

# %%
df
# Out:
#        ID_Perfume                   perfume                brand  is_lokal  \
# 0       HRMN-0001                    glitch              mykonos      True
# 1       HRMN-0002                    invade              mykonos      True
# 2       HRMN-0003                Cafe Drops              mykonos      True
# 3       HRMN-0004                Pink Drops              mykonos      True
# 4       HRMN-0005        Pandan Sticky Rice              mykonos      True
# ...           ...                       ...                  ...       ...
# 25122  FRGN-25123                  floratta          o-boticario     False
# 25123  FRGN-25124           cheval-d-arabie  sultan-pasha-attars     False
# 25124  FRGN-25125                     khaox     darkbeat-parfums     False
# 25125  FRGN-25126                 aoud-no-1  parfumerie-bruckner     False
# 25126  FRGN-25127  narmar-extrait-de-parfum       nilafar-du-nil     False
#
#                                                    Notes
# 0      sicilian bergamot, apple, grapefruit, charred ...
# 1      pink pepper, lavender absolute, juniper., cash...
# 2      orchid, jasmine, coffee, vanilla, caramel, ton...
# 3      strawberry preserve, almond, caramel, milk, he...
# 4      rice, almond, lactonic, jasmine, ylang ylang, ...
# ...                                                  ...
# 25122  ozonic notes, peach, lily-of-the-valley, jasmi...
# 25123  taif rose, indian oud, white rose, olibanum, e...
# 25124  mint, lime, rum, lily-of-the-valley, fig leaf,...
# 25125  apple, peach, saffron, plum, orange blossom, j...
# 25126  cardamom, lavender, juniper, bergamot, clary s...
#
# [25127 rows x 5 columns]

# %% [markdown]
# # Model

# %%
# TF-IDF Vectorization
tfidf = TfidfVectorizer()
tfidf_matrix = tfidf.fit_transform(df['Notes'])

# %%
# Konversi ke tensorflow
tfidf_tensor = tf.convert_to_tensor(tfidf_matrix.toarray(), dtype=tf.float32)

# %%
# Hitung Cosine Similarity dengan TensorFlow
def cosine_similarity_tf(a, b):
    a_norm = tf.nn.l2_normalize(a, axis=1)
    b_norm = tf.nn.l2_normalize(b, axis=1)
    return tf.matmul(a_norm, b_norm, transpose_b=True)

# %%
indices = pd.Series(df.index, index=df['perfume'].str.lower()).drop_duplicates()

# %%
def rekomendasi_lokal_tf(nama_parfum, top_n=10):
    nama_parfum = nama_parfum.lower()
    if nama_parfum not in indices:
        return f"Parfum '{nama_parfum}' tidak ditemukan."

    idx = indices[nama_parfum]

    # Ambil vektor dari parfum input
    input_vec = tfidf_tensor[idx:idx+1]

    # Hitung similarity dengan semua parfum (menggunakan TensorFlow)
    sim_scores = cosine_similarity_tf(input_vec, tfidf_tensor).numpy().flatten()

    # Hilangkan dirinya sendiri
    sim_scores[idx] = -1

    # Urutkan dari skor tertinggi ke rendah
    sorted_indices = np.argsort(sim_scores)[::-1]

    # Filter hanya parfum lokal
    lokal_indices = [i for i in sorted_indices if df.loc[i, 'is_lokal']]
    top_lokal = lokal_indices[:top_n]

    # Siapkan hasil output
    hasil = df.iloc[top_lokal][['ID_Perfume', 'perfume', 'brand', 'Notes']].copy()
    hasil['similarity'] = [round(sim_scores[i], 3) for i in top_lokal]

    return hasil.reset_index(drop=True)

# %%
rekomendasi_lokal_tf("dior-homme-2005", top_n=5)
# Out:
#   ID_Perfume      perfume         brand  \
# 0  HRMN-1047   St. Tropez    Saint Hars
# 1  HRMN-0813     24 Hours     Mandalika
# 2  HRMN-0280     Explorer       Bonjour
# 3  HRMN-0084       Petruk  Project 1945
# 4  HRMN-0353  Mindfulness          MOEN
#
#                                                Notes  similarity
# 0  bergamot, casablanca lily, tahitian vanilla, a...       0.353
# 1  cardamom, lemon, pear, iris, cinnamon, lavende...       0.334
# 2  bergamot, pink pepper, clary sage, haitian vet...       0.332
# 3  lemon, apple, lavender, pepper, leather, carda...       0.329
# 4  verbena, iris, lavender, mint, cardamom, viole...       0.325

# %% [markdown]
# # Save Model

# %%
with open("tfidf_vectorizer.pkl", "wb") as f:
    pickle.dump(tfidf, f)

np.save("tfidf_tensor.npy", tfidf_tensor.numpy())
df.to_csv("parfum_metadata.csv", index=False)
